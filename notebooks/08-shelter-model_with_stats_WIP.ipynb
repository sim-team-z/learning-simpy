# %% [markdown]
# ## Notebook #8 goal
#
# This notebook modifies the main model to integrate the NHPP and the variable stay code together and performs a test run, and "new stuff" :
# - adds send_to_hotel code (done)
# - incorporates Srees viz (done)
# - parameterizes multiple runs (done)
# - updates the mental case to beta distribution

# %% [markdown]
# #### Very basic shelter model
#
# This simpy model is Inspired by car wash example https://simpy.readthedocs.io/en/latest/examples/carwash.html
#
# The parameters in this model are:
# - the client is only 1 person
#     - *this need to make it random from 1-6)*
# - the stay period of client is random, and between 7 days to 365
#     - *this needs to be made into a distribution (or combination of distribution) based on any one of the four cases discussed [here](https://github.com/sim-team-z/learning-simpy/blob/main/README.md)*
# - the number of beds in shelter are 35
# - the clients arrive at the shelter seeking refuge every 7 days.
#     - *this needs to be made variable, perhaps picking an RV from a poisson distribution*
#
#
# This model also turn away clients when at capacity, and keeps count of the number.

# %%
import math
import numpy as np
import pandas as pd
import random
from scipy.stats import poisson
from scipy.stats import beta
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
import simpy
from datetime import datetime
import csv

# %%
#GLOBAL VARIABLES

RANDOM_SEED = 42 # not used
NUM_BEDS = 15  # Number of beds in the shelter
MAX_FAMILY_SIZE = 6 # maximum # of people in the client's family (mom and children)
CASE_DISTRIBUTION = [0.25, 0.25, 0.25, 0.25] # ratio of clients showing up [CAPABLE, CULTURAL CHALLENGES, MENTAL CHALLENGES, SKILLS GAP]
POISSON_ARRIVAL_JAN_AUG =  10 #a family every 10 days
POISSON_ARRIVAL_SEP_DEC = 5 #  a family every 5 days
PROB_THAT_CLIENTS_LIFE_IS_THREATENED = 0.10 #these clients need to be sent to undisclosed hotel
SIM_TIME = 365    # Simulation time in days
NUMBER_OF_RUNS= 5 # the number of simulation iterations we wish to run

class ShelterData(object):
    # an instanc of this class allows for a  persisted data structure across multiple simulation runs
    # where all the details of the simulation can be captured.
    def __init__(self):
        self.data_table = pd.DataFrame({
            'run_number' : [],
            'day': [],
            'month' : [],
            'sent_to_hotel' : [],
            'ppl_turned_away': [],
            'shelter_capacity_left': [],
            'client_case1': [],
            'client_case2': [],
            'client_case3': [],
            'client_case4': []
        })
            
    def append_shelter_data(self,data_array):
        df2 = pd.DataFrame({
        'run_number' : [data_array[0]],
        'day': [data_array[1]],
        'month' : [data_array[2]],
        'sent_to_hotel' : [data_array[3]],
        'ppl_turned_away': [data_array[4]],
        'shelter_capacity_left': [data_array[5]],
        'client_case1': [data_array[6]],
        'client_case2': [data_array[7]],
        'client_case3': [data_array[8]],
        'client_case4': [data_array[9]]
                            })
        return pd.concat([self.data_table,df2])


    
class Shelter(object):
    """A shelter has a limited number of beds (``NUM_BEDS``) to
    host clients.

    Clients have to request one of the beds. When they got one, they
    can start their stay (which takes ``staytime`` minutes).

    """
    referred_clients = 0
    day_of_year = 1
    
    def __init__(self, env, num_beds):
        self.env = env
        self.shelter = simpy.Resource(env, num_beds)
        print('~~SIMULATION STARTUP~~ Shelter has {} beds available'.format(NUM_BEDS - self.shelter.count))
        #self.staytime = staytime
        self.referred_clients = 0
        self.sent_to_hotel = 0

    def get_count_of_referred_clients():
        return self.referred_clients
    
    def increment_count_of_referred_clients():
        self.referred_clients += 1
    
    def stay2(self, client_name, family_size, case):
        #simulates duration of stay for client (and family, if applicable)
        #based on her case (CAPABLE=1, CULTURAL=2, MENTAL=3, SKILLS=4)
        
        if case == 1 : # Capable and quickly back on their feet
            stay_duration = random.randint(7, 2*30)
        elif case == 2: #Language and cultural barrier
            stay_duration = random.randint(9*30, 12*30)
        elif case == 3: #Mental barrier
            stay_duration = random.randint(4*30, 9*30) # TODO this is a long tailed distribution, not uniform. check README.md.
            #need to change
        elif case == 4:
            stay_duration = random.randint(2*30, 6*30)
        
        return stay_duration
        
    
def month(day_num):
    #receives simulation day number and returns the month. 
    #example: receives 32 returns 02 (as the 32nd day of run is feb 1st)
    if day_num == 1095:
        day_num = 1094 # otherwise the last day of the run turns into january!
    day_num= day_num % 365 
    if day_num == 0:
        day_num = 1
    year = "2022"
    # converting to date
    month = datetime.strptime(year + "-" + str(day_num), "%Y-%j").strftime("%m")
    return month
  

        

def number_of_days_next_client_turns_up(current_day):
    #if the day is within first 8 months (Jan - Aug), the rate of clients coming in is slower 
    # than if its between 9-12th (Sept-Dec) months.
    # there should be an option in simpy to find the day of the simulation too
    # 242 days === January 1, 2022 - August 31, 2022
    if current_day < 242:
        return poisson.rvs(POISSON_ARRIVAL_JAN_AUG)
    else:
        return poisson.rvs(POISSON_ARRIVAL_SEP_DEC)
            
def client_family_size():
    return random.randint(1, MAX_FAMILY_SIZE)

def client_case_type():
    caseList = [1,2,3,4]
    return random.choices(caseList, weights=CASE_DISTRIBUTION, k=1)[0]
    

def client(env, client_name, family_size, case_type, shelter_object, shelter_data_object, run_number):
    # The client process (each client has a client_name) arrives potentially 
    # with family (family_size) with a condition (case_type) at the shelter 
    # and requests bed(s).
    if (bernoulli.rvs(PROB_THAT_CLIENTS_LIFE_IS_THREATENED, size=1)[0] == 1):
        #this clients life is under threat, and needs to be sent to a hotel
        shelter_object.sent_to_hotel += family_size
        print("(day {})\t[client] Shelter has sent {} clients (including their family members) \
              with life-threatening situations to undisclosed hotels."
              .format(env.now, shelter_object.sent_to_hotel))
        
        # event! shelter just sent people to hotel, write to the pandas data_table:
        #first , prepare case_array, (all zeros here)
        case_array = [0,0,0,0]
        data_array = [run_number,env.now+1,month(env.now+1),
                      shelter_object.sent_to_hotel,
                      shelter_object.referred_clients,
                      NUM_BEDS - shelter_object.shelter.count]

        #finally, append both data_array and case_array and shove that into the data_table.
        shelter_data_object.data_table = shelter_data_object.append_shelter_data(np.append(data_array,case_array))
        #pd.set_option('expand_frame_repr', False)
        #print(shelter_data_object.data_table)
        
    else:
        #this code block checks if there is room in shelter or not and acts accordingly:
        if (
            (NUM_BEDS - shelter_object.shelter.count == 0) or 
            (NUM_BEDS - shelter_object.shelter.count < family_size)):
            print("(day {})\t[client] !!!!SHELTER AT CAPACITY. only {} available beds. Referring out {} family of {} "
                  .format(env.now,
                          NUM_BEDS - shelter_object.shelter.count,
                          client_name,
                          family_size))

            shelter_object.referred_clients += family_size    
            #referred_clients_count = shelter_object.referred_clients
            print("(day {})\t[client] Shelter has unfortunately turned {} clients (including their family members) away thus far."
                  .format(env.now, shelter_object.referred_clients))

            # event! shelter just turned away people, write to the pandas data_table:
            #first , prepare case_array, (all zeros here)
            case_array = [0,0,0,0]
            data_array = [run_number,env.now+1,month(env.now+1),
                          shelter_object.sent_to_hotel,
                          shelter_object.referred_clients,
                          NUM_BEDS - shelter_object.shelter.count]

            #finally, append both data_array and case_array and shove that into the data_table.
            shelter_data_object.data_table = shelter_data_object.append_shelter_data(np.append(data_array,case_array))
            #pd.set_option('expand_frame_repr', False)
            #print(shelter_data_object.data_table)
            

        else:
            print('(day {})\t[client] {} (family size = {}, case type = {}) arrives the shelter\tavailable beds {}.'
                  .format(env.now, client_name, 
                          family_size, 
                          case_type, 
                          NUM_BEDS - shelter_object.shelter.count))


            beds_taken = []

            for i in range(family_size):    
                beds_taken.append(shelter_object.shelter.request())
                print("(day {})\t[client] {}, family member {} went into shelter\tavailable_beds {}"
                      .format(env.now, client_name, i, NUM_BEDS - shelter_object.shelter.count))

            # event! client and family just went into shelter, write to the pandas data_table:
            #first , prepare case_array
            case_array = []

            if case_type == 1:
                case_array = [family_size,0,0,0]
            elif case_type == 2:
                case_array = [0,family_size,0,0]
            elif case_type == 3:
                case_array = [0,0,family_size,0]
            elif case_type == 4:
                case_array = [0,0,0,family_size]
            #second , prepare data_array
            data_array = [run_number,env.now+1,month(env.now+1),
                          shelter_object.sent_to_hotel,
                          shelter_object.referred_clients,
                          NUM_BEDS - shelter_object.shelter.count]

            #finally, append both data_array and case_array and shove that into the data_table.
            shelter_data_object.data_table = shelter_data_object.append_shelter_data(np.append(data_array,case_array))
            #pd.set_option('expand_frame_repr', False)
            #print(shelter_data_object.data_table)

            # the client and her family's stay starts:
            yield env.timeout(shelter_object.stay2(client_name,family_size,case_type))
            # the client's stay is complete

            for i in range(family_size):
                shelter_object.shelter.release(beds_taken[i])
                print("(day {})\t[client] {}, family member {} came out of shelter\tavailable_beds {}"
                      .format(env.now, client_name, i, NUM_BEDS - shelter_object.shelter.count))

            #event! the client and fam just left shelter, update data_table:
            #first, invert the case_array (as the peeps are leaving)
            case_array = -1*np.array(case_array)
            #second, create data_array:

            data_array = [run_number,env.now+1,month(env.now+1),
                          shelter_object.sent_to_hotel,
                          shelter_object.referred_clients,
                          NUM_BEDS - shelter_object.shelter.count]
            #finally, append both data_array and case_array and shove that into the data_table.
            shelter_data_object.data_table = shelter_data_object.append_shelter_data(np.append(data_array,case_array))
            #pd.set_option('expand_frame_repr', False)
            #print(shelter_data_object.data_table)


            print('(day {})\t[client] {} (family size = {}, case type = {}) LEAVES the shelter\tavailable beds {}'
                  .format(env.now,
                          client_name, 
                          family_size, 
                          case_type, 
                          NUM_BEDS - shelter_object.shelter.count)
                 )
        
        
def setup(env, num_beds, ds, run_nbr):
    

    # Create the shelter  object
    shelter = Shelter(env, num_beds)

    # Create 4 initial clients
    for client_number in range(4):
        env.process(
            client(
                env, 
                'Client %d' % client_number, 
                client_family_size(), 
                client_case_type(), 
                shelter,
                ds,
                run_nbr))

    # Create more clients while the simulation is running
    while True:
        # the following code calls a function which returns the number of days after which the next
        # client(+family) shows up
        yield env.timeout(number_of_days_next_client_turns_up(env.now))
        client_number += 1
        env.process(
            client(env, 
                'Client %i' % client_number, 
                client_family_size(), 
                client_case_type(), 
                shelter,
                ds,
                run_nbr))
    
    

#~~~~~~~ MAIN ~~~~~~~#

#create a persisted shelter data object
shelter_data = ShelterData()

# Setup and start the simulation
random.seed(RANDOM_SEED)  # This helps reproducing the results


for run_nbr in range(NUMBER_OF_RUNS):
    # Create/Reset environment and start the setup process
    env = simpy.Environment()
    env.process(setup(env, NUM_BEDS, shelter_data, run_nbr+1))
    #execute!
    env.run(until=SIM_TIME)
# Out:
# ~~SIMULATION STARTUP~~ Shelter has 15 beds available
# (day 0)	[client] Client 0 (family size = 6, case type = 1) arrives the shelter	available beds 15.
# (day 0)	[client] Client 0, family member 0 went into shelter	available_beds 14
# (day 0)	[client] Client 0, family member 1 went into shelter	available_beds 13
# (day 0)	[client] Client 0, family member 2 went into shelter	available_beds 12
# (day 0)	[client] Client 0, family member 3 went into shelter	available_beds 11
# (day 0)	[client] Client 0, family member 4 went into shelter	available_beds 10
# (day 0)	[client] Client 0, family member 5 went into shelter	available_beds 9
# (day 0)	[client] Client 1 (family size = 6, case type = 2) arrives the shelter	available beds 9.
# (day 0)	[client] Client 1, family member 0 went into shelter	available_beds 8
# (day 0)	[client] Client 1, family member 1 went into shelter	available_beds 7
# (day 0)	[client] Client 1, family member 2 went into shelter	available_beds 6
# (day 0)	[client] Client 1, family member 3 went into shelter	available_beds 5
# (day 0)	[client] Client 1, family member 4 went into shelter	available_beds 4
# (day 0)	[client] Client 1, family member 5 went into shelter	available_beds 3
# (day 0)	[client] Client 2 (family size = 2, case type = 1) arrives the shelter	available beds 3.
# (day 0)	[client] Client 2, family member 0 went into shelter	available_beds 2
# (day 0)	[client] Client 2, family member 1 went into shelter	available_beds 1
# (day 0)	[client] Client 3 (family size = 1, case type = 3) arrives the shelter	available beds 1.
# (day 0)	[client] Client 3, family member 0 went into shelter	available_beds 0
# (day 12)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 4 family of 1
# (day 12)	[client] Shelter has unfortunately turned 1 clients (including their family members) away thus far.
# (day 21)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 5 family of 2
# (day 21)	[client] Shelter has unfortunately turned 3 clients (including their family members) away thus far.
# (day 32)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 6 family of 5
# (day 32)	[client] Shelter has unfortunately turned 8 clients (including their family members) away thus far.
# (day 39)	[client] Shelter has sent 2 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 41)	[client] Client 0, family member 0 came out of shelter	available_beds 1
# (day 41)	[client] Client 0, family member 1 came out of shelter	available_beds 2
# (day 41)	[client] Client 0, family member 2 came out of shelter	available_beds 3
# (day 41)	[client] Client 0, family member 3 came out of shelter	available_beds 4
# (day 41)	[client] Client 0, family member 4 came out of shelter	available_beds 5
# (day 41)	[client] Client 0, family member 5 came out of shelter	available_beds 6
# (day 41)	[client] Client 0 (family size = 6, case type = 1) LEAVES the shelter	available beds 6
# (day 44)	[client] Client 2, family member 0 came out of shelter	available_beds 7
# (day 44)	[client] Client 2, family member 1 came out of shelter	available_beds 8
# (day 44)	[client] Client 2 (family size = 2, case type = 1) LEAVES the shelter	available beds 8
# (day 51)	[client] Client 8 (family size = 6, case type = 3) arrives the shelter	available beds 8.
# (day 51)	[client] Client 8, family member 0 went into shelter	available_beds 7
# (day 51)	[client] Client 8, family member 1 went into shelter	available_beds 6
# (day 51)	[client] Client 8, family member 2 went into shelter	available_beds 5
# (day 51)	[client] Client 8, family member 3 went into shelter	available_beds 4
# (day 51)	[client] Client 8, family member 4 went into shelter	available_beds 3
# (day 51)	[client] Client 8, family member 5 went into shelter	available_beds 2
# (day 57)	[client] Shelter has sent 6 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 68)	[client] Client 10 (family size = 1, case type = 4) arrives the shelter	available beds 2.
# (day 68)	[client] Client 10, family member 0 went into shelter	available_beds 1
# (day 76)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 11 family of 6
# (day 76)	[client] Shelter has unfortunately turned 14 clients (including their family members) away thus far.
# (day 87)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 12 family of 3
# (day 87)	[client] Shelter has unfortunately turned 17 clients (including their family members) away thus far.
# (day 92)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 13 family of 3
# (day 92)	[client] Shelter has unfortunately turned 20 clients (including their family members) away thus far.
# (day 100)	[client] Shelter has sent 10 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 108)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 15 family of 3
# (day 108)	[client] Shelter has unfortunately turned 23 clients (including their family members) away thus far.
# (day 116)	[client] Client 16 (family size = 1, case type = 3) arrives the shelter	available beds 1.
# (day 116)	[client] Client 16, family member 0 went into shelter	available_beds 0
# (day 120)	[client] Shelter has sent 11 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 128)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 18 family of 4
# (day 128)	[client] Shelter has unfortunately turned 27 clients (including their family members) away thus far.
# (day 138)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 19 family of 3
# (day 138)	[client] Shelter has unfortunately turned 30 clients (including their family members) away thus far.
# (day 148)	[client] Client 10, family member 0 came out of shelter	available_beds 1
# (day 148)	[client] Client 10 (family size = 1, case type = 4) LEAVES the shelter	available beds 1
# (day 149)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 20 family of 5
# (day 149)	[client] Shelter has unfortunately turned 35 clients (including their family members) away thus far.
# (day 159)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 21 family of 3
# (day 159)	[client] Shelter has unfortunately turned 38 clients (including their family members) away thus far.
# (day 169)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 22 family of 6
# (day 169)	[client] Shelter has unfortunately turned 44 clients (including their family members) away thus far.
# (day 182)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 23 family of 6
# (day 182)	[client] Shelter has unfortunately turned 50 clients (including their family members) away thus far.
# (day 199)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 24 family of 3
# (day 199)	[client] Shelter has unfortunately turned 53 clients (including their family members) away thus far.
# (day 205)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 25 family of 2
# (day 205)	[client] Shelter has unfortunately turned 55 clients (including their family members) away thus far.
# (day 210)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 26 family of 4
# (day 210)	[client] Shelter has unfortunately turned 59 clients (including their family members) away thus far.
# (day 220)	[client] Shelter has sent 17 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 227)	[client] Client 8, family member 0 came out of shelter	available_beds 2
# (day 227)	[client] Client 8, family member 1 came out of shelter	available_beds 3
# (day 227)	[client] Client 8, family member 2 came out of shelter	available_beds 4
# (day 227)	[client] Client 8, family member 3 came out of shelter	available_beds 5
# (day 227)	[client] Client 8, family member 4 came out of shelter	available_beds 6
# (day 227)	[client] Client 8, family member 5 came out of shelter	available_beds 7
# (day 227)	[client] Client 8 (family size = 6, case type = 3) LEAVES the shelter	available beds 7
# (day 228)	[client] Client 3, family member 0 came out of shelter	available_beds 8
# (day 228)	[client] Client 3 (family size = 1, case type = 3) LEAVES the shelter	available beds 8
# (day 230)	[client] Client 28 (family size = 2, case type = 2) arrives the shelter	available beds 8.
# (day 230)	[client] Client 28, family member 0 went into shelter	available_beds 7
# (day 230)	[client] Client 28, family member 1 went into shelter	available_beds 6
# (day 238)	[client] Client 29 (family size = 6, case type = 2) arrives the shelter	available beds 6.
# (day 238)	[client] Client 29, family member 0 went into shelter	available_beds 5
# (day 238)	[client] Client 29, family member 1 went into shelter	available_beds 4
# (day 238)	[client] Client 29, family member 2 went into shelter	available_beds 3
# (day 238)	[client] Client 29, family member 3 went into shelter	available_beds 2
# (day 238)	[client] Client 29, family member 4 went into shelter	available_beds 1
# (day 238)	[client] Client 29, family member 5 went into shelter	available_beds 0
# (day 246)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 30 family of 6
# (day 246)	[client] Shelter has unfortunately turned 65 clients (including their family members) away thus far.
# (day 251)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 31 family of 6
# (day 251)	[client] Shelter has unfortunately turned 71 clients (including their family members) away thus far.
# (day 258)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 32 family of 6
# (day 258)	[client] Shelter has unfortunately turned 77 clients (including their family members) away thus far.
# (day 261)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 33 family of 4
# (day 261)	[client] Shelter has unfortunately turned 81 clients (including their family members) away thus far.
# (day 262)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 34 family of 6
# (day 262)	[client] Shelter has unfortunately turned 87 clients (including their family members) away thus far.
# (day 267)	[client] Shelter has sent 19 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 272)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 36 family of 1
# (day 272)	[client] Shelter has unfortunately turned 88 clients (including their family members) away thus far.
# (day 276)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 37 family of 1
# (day 276)	[client] Shelter has unfortunately turned 89 clients (including their family members) away thus far.
# (day 281)	[client] Client 1, family member 0 came out of shelter	available_beds 1
# (day 281)	[client] Client 1, family member 1 came out of shelter	available_beds 2
# (day 281)	[client] Client 1, family member 2 came out of shelter	available_beds 3
# (day 281)	[client] Client 1, family member 3 came out of shelter	available_beds 4
# (day 281)	[client] Client 1, family member 4 came out of shelter	available_beds 5
# (day 281)	[client] Client 1, family member 5 came out of shelter	available_beds 6
# (day 281)	[client] Client 1 (family size = 6, case type = 2) LEAVES the shelter	available beds 6
# (day 286)	[client] Client 38 (family size = 4, case type = 2) arrives the shelter	available beds 6.
# (day 286)	[client] Client 38, family member 0 went into shelter	available_beds 5
# (day 286)	[client] Client 38, family member 1 went into shelter	available_beds 4
# (day 286)	[client] Client 38, family member 2 went into shelter	available_beds 3
# (day 286)	[client] Client 38, family member 3 went into shelter	available_beds 2
# (day 288)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 39 family of 5
# (day 288)	[client] Shelter has unfortunately turned 94 clients (including their family members) away thus far.
# (day 293)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 40 family of 3
# (day 293)	[client] Shelter has unfortunately turned 97 clients (including their family members) away thus far.
# (day 296)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 41 family of 4
# (day 296)	[client] Shelter has unfortunately turned 101 clients (including their family members) away thus far.
# (day 304)	[client] Shelter has sent 25 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 309)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 43 family of 3
# (day 309)	[client] Shelter has unfortunately turned 104 clients (including their family members) away thus far.
# (day 316)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 44 family of 6
# (day 316)	[client] Shelter has unfortunately turned 110 clients (including their family members) away thus far.
# (day 321)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 45 family of 3
# (day 321)	[client] Shelter has unfortunately turned 113 clients (including their family members) away thus far.
# (day 328)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 46 family of 4
# (day 328)	[client] Shelter has unfortunately turned 117 clients (including their family members) away thus far.
# (day 334)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 47 family of 4
# (day 334)	[client] Shelter has unfortunately turned 121 clients (including their family members) away thus far.
# (day 342)	[client] Client 48 (family size = 2, case type = 3) arrives the shelter	available beds 2.
# (day 342)	[client] Client 48, family member 0 went into shelter	available_beds 1
# (day 342)	[client] Client 48, family member 1 went into shelter	available_beds 0
# (day 347)	[client] Shelter has sent 26 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 355)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 50 family of 2
# (day 355)	[client] Shelter has unfortunately turned 123 clients (including their family members) away thus far.
# (day 361)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 51 family of 6
# (day 361)	[client] Shelter has unfortunately turned 129 clients (including their family members) away thus far.
# ~~SIMULATION STARTUP~~ Shelter has 15 beds available
# (day 0)	[client] Client 0 (family size = 1, case type = 2) arrives the shelter	available beds 15.
# (day 0)	[client] Client 0, family member 0 went into shelter	available_beds 14
# (day 0)	[client] Client 1 (family size = 5, case type = 4) arrives the shelter	available beds 14.
# (day 0)	[client] Client 1, family member 0 went into shelter	available_beds 13
# (day 0)	[client] Client 1, family member 1 went into shelter	available_beds 12
# (day 0)	[client] Client 1, family member 2 went into shelter	available_beds 11
# (day 0)	[client] Client 1, family member 3 went into shelter	available_beds 10
# (day 0)	[client] Client 1, family member 4 went into shelter	available_beds 9
# (day 0)	[client] Client 2 (family size = 5, case type = 2) arrives the shelter	available beds 9.
# (day 0)	[client] Client 2, family member 0 went into shelter	available_beds 8
# (day 0)	[client] Client 2, family member 1 went into shelter	available_beds 7
# (day 0)	[client] Client 2, family member 2 went into shelter	available_beds 6
# (day 0)	[client] Client 2, family member 3 went into shelter	available_beds 5
# (day 0)	[client] Client 2, family member 4 went into shelter	available_beds 4
# (day 0)	[client] !!!!SHELTER AT CAPACITY. only 4 available beds. Referring out Client 3 family of 5
# (day 0)	[client] Shelter has unfortunately turned 5 clients (including their family members) away thus far.
# (day 7)	[client] !!!!SHELTER AT CAPACITY. only 4 available beds. Referring out Client 4 family of 6
# (day 7)	[client] Shelter has unfortunately turned 11 clients (including their family members) away thus far.
# (day 17)	[client] Client 5 (family size = 3, case type = 4) arrives the shelter	available beds 4.
# (day 17)	[client] Client 5, family member 0 went into shelter	available_beds 3
# (day 17)	[client] Client 5, family member 1 went into shelter	available_beds 2
# (day 17)	[client] Client 5, family member 2 went into shelter	available_beds 1
# (day 23)	[client] Client 6 (family size = 1, case type = 2) arrives the shelter	available beds 1.
# (day 23)	[client] Client 6, family member 0 went into shelter	available_beds 0
# (day 32)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 7 family of 4
# (day 32)	[client] Shelter has unfortunately turned 15 clients (including their family members) away thus far.
# (day 43)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 8 family of 6
# (day 43)	[client] Shelter has unfortunately turned 21 clients (including their family members) away thus far.
# (day 62)	[client] Shelter has sent 3 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 75)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 10 family of 2
# (day 75)	[client] Shelter has unfortunately turned 23 clients (including their family members) away thus far.
# (day 82)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 11 family of 1
# (day 82)	[client] Shelter has unfortunately turned 24 clients (including their family members) away thus far.
# (day 94)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 12 family of 3
# (day 94)	[client] Shelter has unfortunately turned 27 clients (including their family members) away thus far.
# (day 104)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 13 family of 5
# (day 104)	[client] Shelter has unfortunately turned 32 clients (including their family members) away thus far.
# (day 115)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 14 family of 2
# (day 115)	[client] Shelter has unfortunately turned 34 clients (including their family members) away thus far.
# (day 120)	[client] Client 5, family member 0 came out of shelter	available_beds 1
# (day 120)	[client] Client 5, family member 1 came out of shelter	available_beds 2
# (day 120)	[client] Client 5, family member 2 came out of shelter	available_beds 3
# (day 120)	[client] Client 5 (family size = 3, case type = 4) LEAVES the shelter	available beds 3
# (day 125)	[client] Client 15 (family size = 2, case type = 3) arrives the shelter	available beds 3.
# (day 125)	[client] Client 15, family member 0 went into shelter	available_beds 2
# (day 125)	[client] Client 15, family member 1 went into shelter	available_beds 1
# (day 137)	[client] Client 16 (family size = 1, case type = 3) arrives the shelter	available beds 1.
# (day 137)	[client] Client 16, family member 0 went into shelter	available_beds 0
# (day 147)	[client] Client 1, family member 0 came out of shelter	available_beds 1
# (day 147)	[client] Client 1, family member 1 came out of shelter	available_beds 2
# (day 147)	[client] Client 1, family member 2 came out of shelter	available_beds 3
# (day 147)	[client] Client 1, family member 3 came out of shelter	available_beds 4
# (day 147)	[client] Client 1, family member 4 came out of shelter	available_beds 5
# (day 147)	[client] Client 1 (family size = 5, case type = 4) LEAVES the shelter	available beds 5
# (day 147)	[client] Client 17 (family size = 1, case type = 1) arrives the shelter	available beds 5.
# (day 147)	[client] Client 17, family member 0 went into shelter	available_beds 4
# (day 160)	[client] Client 18 (family size = 3, case type = 1) arrives the shelter	available beds 4.
# (day 160)	[client] Client 18, family member 0 went into shelter	available_beds 3
# (day 160)	[client] Client 18, family member 1 went into shelter	available_beds 2
# (day 160)	[client] Client 18, family member 2 went into shelter	available_beds 1
# (day 173)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 19 family of 5
# (day 173)	[client] Shelter has unfortunately turned 39 clients (including their family members) away thus far.
# (day 177)	[client] Client 17, family member 0 came out of shelter	available_beds 2
# (day 177)	[client] Client 17 (family size = 1, case type = 1) LEAVES the shelter	available beds 2
# (day 182)	[client] Client 18, family member 0 came out of shelter	available_beds 3
# (day 182)	[client] Client 18, family member 1 came out of shelter	available_beds 4
# (day 182)	[client] Client 18, family member 2 came out of shelter	available_beds 5
# (day 182)	[client] Client 18 (family size = 3, case type = 1) LEAVES the shelter	available beds 5
# (day 183)	[client] Client 20 (family size = 1, case type = 3) arrives the shelter	available beds 5.
# (day 183)	[client] Client 20, family member 0 went into shelter	available_beds 4
# (day 194)	[client] Shelter has sent 8 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 205)	[client] Shelter has sent 10 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 210)	[client] !!!!SHELTER AT CAPACITY. only 4 available beds. Referring out Client 23 family of 5
# (day 210)	[client] Shelter has unfortunately turned 44 clients (including their family members) away thus far.
# (day 216)	[client] !!!!SHELTER AT CAPACITY. only 4 available beds. Referring out Client 24 family of 5
# (day 216)	[client] Shelter has unfortunately turned 49 clients (including their family members) away thus far.
# (day 227)	[client] Client 25 (family size = 4, case type = 4) arrives the shelter	available beds 4.
# (day 227)	[client] Client 25, family member 0 went into shelter	available_beds 3
# (day 227)	[client] Client 25, family member 1 went into shelter	available_beds 2
# (day 227)	[client] Client 25, family member 2 went into shelter	available_beds 1
# (day 227)	[client] Client 25, family member 3 went into shelter	available_beds 0
# (day 233)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 26 family of 5
# (day 233)	[client] Shelter has unfortunately turned 54 clients (including their family members) away thus far.
# (day 241)	[client] Shelter has sent 16 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 250)	[client] Shelter has sent 19 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 255)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 29 family of 6
# (day 255)	[client] Shelter has unfortunately turned 60 clients (including their family members) away thus far.
# (day 261)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 30 family of 4
# (day 261)	[client] Shelter has unfortunately turned 64 clients (including their family members) away thus far.
# (day 267)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 31 family of 4
# (day 267)	[client] Shelter has unfortunately turned 68 clients (including their family members) away thus far.
# (day 271)	[client] Client 0, family member 0 came out of shelter	available_beds 1
# (day 271)	[client] Client 0 (family size = 1, case type = 2) LEAVES the shelter	available beds 1
# (day 276)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 32 family of 2
# (day 276)	[client] Shelter has unfortunately turned 70 clients (including their family members) away thus far.
# (day 282)	[client] Client 33 (family size = 1, case type = 3) arrives the shelter	available beds 1.
# (day 282)	[client] Client 33, family member 0 went into shelter	available_beds 0
# (day 284)	[client] Client 2, family member 0 came out of shelter	available_beds 1
# (day 284)	[client] Client 2, family member 1 came out of shelter	available_beds 2
# (day 284)	[client] Client 2, family member 2 came out of shelter	available_beds 3
# (day 284)	[client] Client 2, family member 3 came out of shelter	available_beds 4
# (day 284)	[client] Client 2, family member 4 came out of shelter	available_beds 5
# (day 284)	[client] Client 2 (family size = 5, case type = 2) LEAVES the shelter	available beds 5
# (day 288)	[client] Client 34 (family size = 5, case type = 1) arrives the shelter	available beds 5.
# (day 288)	[client] Client 34, family member 0 went into shelter	available_beds 4
# (day 288)	[client] Client 34, family member 1 went into shelter	available_beds 3
# (day 288)	[client] Client 34, family member 2 went into shelter	available_beds 2
# (day 288)	[client] Client 34, family member 3 went into shelter	available_beds 1
# (day 288)	[client] Client 34, family member 4 went into shelter	available_beds 0
# (day 293)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 35 family of 6
# (day 293)	[client] Shelter has unfortunately turned 76 clients (including their family members) away thus far.
# (day 296)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 36 family of 2
# (day 296)	[client] Shelter has unfortunately turned 78 clients (including their family members) away thus far.
# (day 297)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 37 family of 1
# (day 297)	[client] Shelter has unfortunately turned 79 clients (including their family members) away thus far.
# (day 299)	[client] Client 34, family member 0 came out of shelter	available_beds 1
# (day 299)	[client] Client 34, family member 1 came out of shelter	available_beds 2
# (day 299)	[client] Client 34, family member 2 came out of shelter	available_beds 3
# (day 299)	[client] Client 34, family member 3 came out of shelter	available_beds 4
# (day 299)	[client] Client 34, family member 4 came out of shelter	available_beds 5
# (day 299)	[client] Client 34 (family size = 5, case type = 1) LEAVES the shelter	available beds 5
# (day 300)	[client] Shelter has sent 20 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 301)	[client] Client 39 (family size = 3, case type = 3) arrives the shelter	available beds 5.
# (day 301)	[client] Client 39, family member 0 went into shelter	available_beds 4
# (day 301)	[client] Client 39, family member 1 went into shelter	available_beds 3
# (day 301)	[client] Client 39, family member 2 went into shelter	available_beds 2
# (day 308)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 40 family of 5
# (day 308)	[client] Shelter has unfortunately turned 84 clients (including their family members) away thus far.
# (day 313)	[client] Client 6, family member 0 came out of shelter	available_beds 3
# (day 313)	[client] Client 6 (family size = 1, case type = 2) LEAVES the shelter	available beds 3
# (day 313)	[client] !!!!SHELTER AT CAPACITY. only 3 available beds. Referring out Client 41 family of 5
# (day 313)	[client] Shelter has unfortunately turned 89 clients (including their family members) away thus far.
# (day 317)	[client] Client 42 (family size = 2, case type = 4) arrives the shelter	available beds 3.
# (day 317)	[client] Client 42, family member 0 went into shelter	available_beds 2
# (day 317)	[client] Client 42, family member 1 went into shelter	available_beds 1
# (day 319)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 43 family of 4
# (day 319)	[client] Shelter has unfortunately turned 93 clients (including their family members) away thus far.
# (day 320)	[client] Client 20, family member 0 came out of shelter	available_beds 2
# (day 320)	[client] Client 20 (family size = 1, case type = 3) LEAVES the shelter	available beds 2
# (day 323)	[client] Shelter has sent 21 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 327)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 45 family of 3
# (day 327)	[client] Shelter has unfortunately turned 96 clients (including their family members) away thus far.
# (day 337)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 46 family of 4
# (day 337)	[client] Shelter has unfortunately turned 100 clients (including their family members) away thus far.
# (day 346)	[client] Shelter has sent 22 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 350)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 48 family of 6
# (day 350)	[client] Shelter has unfortunately turned 106 clients (including their family members) away thus far.
# (day 359)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 49 family of 4
# (day 359)	[client] Shelter has unfortunately turned 110 clients (including their family members) away thus far.
# (day 364)	[client] Client 50 (family size = 1, case type = 1) arrives the shelter	available beds 2.
# (day 364)	[client] Client 50, family member 0 went into shelter	available_beds 1
# ~~SIMULATION STARTUP~~ Shelter has 15 beds available
# (day 0)	[client] Client 0 (family size = 5, case type = 2) arrives the shelter	available beds 15.
# (day 0)	[client] Client 0, family member 0 went into shelter	available_beds 14
# (day 0)	[client] Client 0, family member 1 went into shelter	available_beds 13
# (day 0)	[client] Client 0, family member 2 went into shelter	available_beds 12
# (day 0)	[client] Client 0, family member 3 went into shelter	available_beds 11
# (day 0)	[client] Client 0, family member 4 went into shelter	available_beds 10
# (day 0)	[client] Client 1 (family size = 4, case type = 1) arrives the shelter	available beds 10.
# (day 0)	[client] Client 1, family member 0 went into shelter	available_beds 9
# (day 0)	[client] Client 1, family member 1 went into shelter	available_beds 8
# (day 0)	[client] Client 1, family member 2 went into shelter	available_beds 7
# (day 0)	[client] Client 1, family member 3 went into shelter	available_beds 6
# (day 0)	[client] Client 2 (family size = 4, case type = 1) arrives the shelter	available beds 6.
# (day 0)	[client] Client 2, family member 0 went into shelter	available_beds 5
# (day 0)	[client] Client 2, family member 1 went into shelter	available_beds 4
# (day 0)	[client] Client 2, family member 2 went into shelter	available_beds 3
# (day 0)	[client] Client 2, family member 3 went into shelter	available_beds 2
# (day 0)	[client] Client 3 (family size = 1, case type = 2) arrives the shelter	available beds 2.
# (day 0)	[client] Client 3, family member 0 went into shelter	available_beds 1
# (day 9)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 4 family of 5
# (day 9)	[client] Shelter has unfortunately turned 5 clients (including their family members) away thus far.
# (day 10)	[client] Client 2, family member 0 came out of shelter	available_beds 2
# (day 10)	[client] Client 2, family member 1 came out of shelter	available_beds 3
# (day 10)	[client] Client 2, family member 2 came out of shelter	available_beds 4
# (day 10)	[client] Client 2, family member 3 came out of shelter	available_beds 5
# (day 10)	[client] Client 2 (family size = 4, case type = 1) LEAVES the shelter	available beds 5
# (day 13)	[client] Client 1, family member 0 came out of shelter	available_beds 6
# (day 13)	[client] Client 1, family member 1 came out of shelter	available_beds 7
# (day 13)	[client] Client 1, family member 2 came out of shelter	available_beds 8
# (day 13)	[client] Client 1, family member 3 came out of shelter	available_beds 9
# (day 13)	[client] Client 1 (family size = 4, case type = 1) LEAVES the shelter	available beds 9
# (day 17)	[client] Client 5 (family size = 1, case type = 4) arrives the shelter	available beds 9.
# (day 17)	[client] Client 5, family member 0 went into shelter	available_beds 8
# (day 28)	[client] Client 6 (family size = 2, case type = 1) arrives the shelter	available beds 8.
# (day 28)	[client] Client 6, family member 0 went into shelter	available_beds 7
# (day 28)	[client] Client 6, family member 1 went into shelter	available_beds 6
# (day 40)	[client] Client 7 (family size = 4, case type = 1) arrives the shelter	available beds 6.
# (day 40)	[client] Client 7, family member 0 went into shelter	available_beds 5
# (day 40)	[client] Client 7, family member 1 went into shelter	available_beds 4
# (day 40)	[client] Client 7, family member 2 went into shelter	available_beds 3
# (day 40)	[client] Client 7, family member 3 went into shelter	available_beds 2
# (day 50)	[client] Client 8 (family size = 1, case type = 1) arrives the shelter	available beds 2.
# (day 50)	[client] Client 8, family member 0 went into shelter	available_beds 1
# (day 57)	[client] Client 8, family member 0 came out of shelter	available_beds 2
# (day 57)	[client] Client 8 (family size = 1, case type = 1) LEAVES the shelter	available beds 2
# (day 61)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 9 family of 4
# (day 61)	[client] Shelter has unfortunately turned 9 clients (including their family members) away thus far.
# (day 66)	[client] Client 6, family member 0 came out of shelter	available_beds 3
# (day 66)	[client] Client 6, family member 1 came out of shelter	available_beds 4
# (day 66)	[client] Client 6 (family size = 2, case type = 1) LEAVES the shelter	available beds 4
# (day 68)	[client] Client 10 (family size = 4, case type = 2) arrives the shelter	available beds 4.
# (day 68)	[client] Client 10, family member 0 went into shelter	available_beds 3
# (day 68)	[client] Client 10, family member 1 went into shelter	available_beds 2
# (day 68)	[client] Client 10, family member 2 went into shelter	available_beds 1
# (day 68)	[client] Client 10, family member 3 went into shelter	available_beds 0
# (day 72)	[client] Client 7, family member 0 came out of shelter	available_beds 1
# (day 72)	[client] Client 7, family member 1 came out of shelter	available_beds 2
# (day 72)	[client] Client 7, family member 2 came out of shelter	available_beds 3
# (day 72)	[client] Client 7, family member 3 came out of shelter	available_beds 4
# (day 72)	[client] Client 7 (family size = 4, case type = 1) LEAVES the shelter	available beds 4
# (day 78)	[client] !!!!SHELTER AT CAPACITY. only 4 available beds. Referring out Client 11 family of 6
# (day 78)	[client] Shelter has unfortunately turned 15 clients (including their family members) away thus far.
# (day 89)	[client] Shelter has sent 5 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 109)	[client] Client 13 (family size = 4, case type = 1) arrives the shelter	available beds 4.
# (day 109)	[client] Client 13, family member 0 went into shelter	available_beds 3
# (day 109)	[client] Client 13, family member 1 went into shelter	available_beds 2
# (day 109)	[client] Client 13, family member 2 went into shelter	available_beds 1
# (day 109)	[client] Client 13, family member 3 went into shelter	available_beds 0
# (day 112)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 14 family of 2
# (day 112)	[client] Shelter has unfortunately turned 17 clients (including their family members) away thus far.
# (day 122)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 15 family of 5
# (day 122)	[client] Shelter has unfortunately turned 22 clients (including their family members) away thus far.
# (day 133)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 16 family of 1
# (day 133)	[client] Shelter has unfortunately turned 23 clients (including their family members) away thus far.
# (day 134)	[client] Client 13, family member 0 came out of shelter	available_beds 1
# (day 134)	[client] Client 13, family member 1 came out of shelter	available_beds 2
# (day 134)	[client] Client 13, family member 2 came out of shelter	available_beds 3
# (day 134)	[client] Client 13, family member 3 came out of shelter	available_beds 4
# (day 134)	[client] Client 13 (family size = 4, case type = 1) LEAVES the shelter	available beds 4
# (day 144)	[client] Client 17 (family size = 1, case type = 1) arrives the shelter	available beds 4.
# (day 144)	[client] Client 17, family member 0 went into shelter	available_beds 3
# (day 155)	[client] !!!!SHELTER AT CAPACITY. only 3 available beds. Referring out Client 18 family of 5
# (day 155)	[client] Shelter has unfortunately turned 28 clients (including their family members) away thus far.
# (day 162)	[client] !!!!SHELTER AT CAPACITY. only 3 available beds. Referring out Client 19 family of 5
# (day 162)	[client] Shelter has unfortunately turned 33 clients (including their family members) away thus far.
# (day 169)	[client] !!!!SHELTER AT CAPACITY. only 3 available beds. Referring out Client 20 family of 5
# (day 169)	[client] Shelter has unfortunately turned 38 clients (including their family members) away thus far.
# (day 181)	[client] Client 17, family member 0 came out of shelter	available_beds 4
# (day 181)	[client] Client 17 (family size = 1, case type = 1) LEAVES the shelter	available beds 4
# (day 181)	[client] Client 21 (family size = 2, case type = 1) arrives the shelter	available beds 4.
# (day 181)	[client] Client 21, family member 0 went into shelter	available_beds 3
# (day 181)	[client] Client 21, family member 1 went into shelter	available_beds 2
# (day 185)	[client] Client 5, family member 0 came out of shelter	available_beds 3
# (day 185)	[client] Client 5 (family size = 1, case type = 4) LEAVES the shelter	available beds 3
# (day 189)	[client] !!!!SHELTER AT CAPACITY. only 3 available beds. Referring out Client 22 family of 6
# (day 189)	[client] Shelter has unfortunately turned 44 clients (including their family members) away thus far.
# (day 192)	[client] Client 21, family member 0 came out of shelter	available_beds 4
# (day 192)	[client] Client 21, family member 1 came out of shelter	available_beds 5
# (day 192)	[client] Client 21 (family size = 2, case type = 1) LEAVES the shelter	available beds 5
# (day 203)	[client] Client 23 (family size = 4, case type = 1) arrives the shelter	available beds 5.
# (day 203)	[client] Client 23, family member 0 went into shelter	available_beds 4
# (day 203)	[client] Client 23, family member 1 went into shelter	available_beds 3
# (day 203)	[client] Client 23, family member 2 went into shelter	available_beds 2
# (day 203)	[client] Client 23, family member 3 went into shelter	available_beds 1
# (day 215)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 24 family of 2
# (day 215)	[client] Shelter has unfortunately turned 46 clients (including their family members) away thus far.
# (day 225)	[client] Client 25 (family size = 1, case type = 3) arrives the shelter	available beds 1.
# (day 225)	[client] Client 25, family member 0 went into shelter	available_beds 0
# (day 234)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 26 family of 6
# (day 234)	[client] Shelter has unfortunately turned 52 clients (including their family members) away thus far.
# (day 242)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 27 family of 5
# (day 242)	[client] Shelter has unfortunately turned 57 clients (including their family members) away thus far.
# (day 246)	[client] Client 23, family member 0 came out of shelter	available_beds 1
# (day 246)	[client] Client 23, family member 1 came out of shelter	available_beds 2
# (day 246)	[client] Client 23, family member 2 came out of shelter	available_beds 3
# (day 246)	[client] Client 23, family member 3 came out of shelter	available_beds 4
# (day 246)	[client] Client 23 (family size = 4, case type = 1) LEAVES the shelter	available beds 4
# (day 246)	[client] Client 28 (family size = 3, case type = 1) arrives the shelter	available beds 4.
# (day 246)	[client] Client 28, family member 0 went into shelter	available_beds 3
# (day 246)	[client] Client 28, family member 1 went into shelter	available_beds 2
# (day 246)	[client] Client 28, family member 2 went into shelter	available_beds 1
# (day 251)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 29 family of 3
# (day 251)	[client] Shelter has unfortunately turned 60 clients (including their family members) away thus far.
# (day 254)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 30 family of 4
# (day 254)	[client] Shelter has unfortunately turned 64 clients (including their family members) away thus far.
# (day 258)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 31 family of 6
# (day 258)	[client] Shelter has unfortunately turned 70 clients (including their family members) away thus far.
# (day 263)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 32 family of 3
# (day 263)	[client] Shelter has unfortunately turned 73 clients (including their family members) away thus far.
# (day 272)	[client] Client 33 (family size = 1, case type = 1) arrives the shelter	available beds 1.
# (day 272)	[client] Client 33, family member 0 went into shelter	available_beds 0
# (day 279)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 34 family of 5
# (day 279)	[client] Shelter has unfortunately turned 78 clients (including their family members) away thus far.
# (day 285)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 35 family of 1
# (day 285)	[client] Shelter has unfortunately turned 79 clients (including their family members) away thus far.
# (day 292)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 36 family of 5
# (day 292)	[client] Shelter has unfortunately turned 84 clients (including their family members) away thus far.
# (day 298)	[client] Client 28, family member 0 came out of shelter	available_beds 1
# (day 298)	[client] Client 28, family member 1 came out of shelter	available_beds 2
# (day 298)	[client] Client 28, family member 2 came out of shelter	available_beds 3
# (day 298)	[client] Client 28 (family size = 3, case type = 1) LEAVES the shelter	available beds 3
# (day 298)	[client] Client 37 (family size = 3, case type = 4) arrives the shelter	available beds 3.
# (day 298)	[client] Client 37, family member 0 went into shelter	available_beds 2
# (day 298)	[client] Client 37, family member 1 went into shelter	available_beds 1
# (day 298)	[client] Client 37, family member 2 went into shelter	available_beds 0
# (day 301)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 38 family of 2
# (day 301)	[client] Shelter has unfortunately turned 86 clients (including their family members) away thus far.
# (day 308)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 39 family of 2
# (day 308)	[client] Shelter has unfortunately turned 88 clients (including their family members) away thus far.
# (day 318)	[client] Client 33, family member 0 came out of shelter	available_beds 1
# (day 318)	[client] Client 33 (family size = 1, case type = 1) LEAVES the shelter	available beds 1
# (day 319)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 40 family of 5
# (day 319)	[client] Shelter has unfortunately turned 93 clients (including their family members) away thus far.
# (day 324)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 41 family of 5
# (day 324)	[client] Shelter has unfortunately turned 98 clients (including their family members) away thus far.
# (day 332)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 42 family of 6
# (day 332)	[client] Shelter has unfortunately turned 104 clients (including their family members) away thus far.
# (day 338)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 43 family of 6
# (day 338)	[client] Shelter has unfortunately turned 110 clients (including their family members) away thus far.
# (day 340)	[client] Client 0, family member 0 came out of shelter	available_beds 2
# (day 340)	[client] Client 0, family member 1 came out of shelter	available_beds 3
# (day 340)	[client] Client 0, family member 2 came out of shelter	available_beds 4
# (day 340)	[client] Client 0, family member 3 came out of shelter	available_beds 5
# (day 340)	[client] Client 0, family member 4 came out of shelter	available_beds 6
# (day 340)	[client] Client 0 (family size = 5, case type = 2) LEAVES the shelter	available beds 6
# (day 348)	[client] Client 44 (family size = 3, case type = 4) arrives the shelter	available beds 6.
# (day 348)	[client] Client 44, family member 0 went into shelter	available_beds 5
# (day 348)	[client] Client 44, family member 1 went into shelter	available_beds 4
# (day 348)	[client] Client 44, family member 2 went into shelter	available_beds 3
# (day 353)	[client] Client 3, family member 0 came out of shelter	available_beds 4
# (day 353)	[client] Client 3 (family size = 1, case type = 2) LEAVES the shelter	available beds 4
# (day 358)	[client] Client 45 (family size = 2, case type = 2) arrives the shelter	available beds 4.
# (day 358)	[client] Client 45, family member 0 went into shelter	available_beds 3
# (day 358)	[client] Client 45, family member 1 went into shelter	available_beds 2
# ~~SIMULATION STARTUP~~ Shelter has 15 beds available
# (day 0)	[client] Client 0 (family size = 6, case type = 3) arrives the shelter	available beds 15.
# (day 0)	[client] Client 0, family member 0 went into shelter	available_beds 14
# (day 0)	[client] Client 0, family member 1 went into shelter	available_beds 13
# (day 0)	[client] Client 0, family member 2 went into shelter	available_beds 12
# (day 0)	[client] Client 0, family member 3 went into shelter	available_beds 11
# (day 0)	[client] Client 0, family member 4 went into shelter	available_beds 10
# (day 0)	[client] Client 0, family member 5 went into shelter	available_beds 9
# (day 0)	[client] Client 1 (family size = 3, case type = 2) arrives the shelter	available beds 9.
# (day 0)	[client] Client 1, family member 0 went into shelter	available_beds 8
# (day 0)	[client] Client 1, family member 1 went into shelter	available_beds 7
# (day 0)	[client] Client 1, family member 2 went into shelter	available_beds 6
# (day 0)	[client] Client 2 (family size = 2, case type = 3) arrives the shelter	available beds 6.
# (day 0)	[client] Client 2, family member 0 went into shelter	available_beds 5
# (day 0)	[client] Client 2, family member 1 went into shelter	available_beds 4
# (day 0)	[client] Client 3 (family size = 2, case type = 3) arrives the shelter	available beds 4.
# (day 0)	[client] Client 3, family member 0 went into shelter	available_beds 3
# (day 0)	[client] Client 3, family member 1 went into shelter	available_beds 2
# (day 7)	[client] Client 4 (family size = 1, case type = 1) arrives the shelter	available beds 2.
# (day 7)	[client] Client 4, family member 0 went into shelter	available_beds 1
# (day 16)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 5 family of 3
# (day 16)	[client] Shelter has unfortunately turned 3 clients (including their family members) away thus far.
# (day 24)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 6 family of 3
# (day 24)	[client] Shelter has unfortunately turned 6 clients (including their family members) away thus far.
# (day 29)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 7 family of 6
# (day 29)	[client] Shelter has unfortunately turned 12 clients (including their family members) away thus far.
# (day 40)	[client] Shelter has sent 2 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 41)	[client] Client 4, family member 0 came out of shelter	available_beds 2
# ...
# (day 355)	[client] Client 42, family member 3 came out of shelter	available_beds 4
# (day 355)	[client] Client 42, family member 4 came out of shelter	available_beds 5
# (day 355)	[client] Client 42 (family size = 5, case type = 1) LEAVES the shelter	available beds 5
# (day 355)	[client] Client 52 (family size = 5, case type = 2) arrives the shelter	available beds 5.
# (day 355)	[client] Client 52, family member 0 went into shelter	available_beds 4
# (day 355)	[client] Client 52, family member 1 went into shelter	available_beds 3
# (day 355)	[client] Client 52, family member 2 went into shelter	available_beds 2
# (day 355)	[client] Client 52, family member 3 went into shelter	available_beds 1
# (day 355)	[client] Client 52, family member 4 went into shelter	available_beds 0
# (day 360)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 53 family of 3
# (day 360)	[client] Shelter has unfortunately turned 131 clients (including their family members) away thus far.
# (day 361)	[client] Client 32, family member 0 came out of shelter	available_beds 1
# (day 361)	[client] Client 32 (family size = 1, case type = 4) LEAVES the shelter	available beds 1
# ~~SIMULATION STARTUP~~ Shelter has 15 beds available
# (day 0)	[client] Client 0 (family size = 3, case type = 3) arrives the shelter	available beds 15.
# (day 0)	[client] Client 0, family member 0 went into shelter	available_beds 14
# (day 0)	[client] Client 0, family member 1 went into shelter	available_beds 13
# (day 0)	[client] Client 0, family member 2 went into shelter	available_beds 12
# (day 0)	[client] Client 1 (family size = 2, case type = 2) arrives the shelter	available beds 12.
# (day 0)	[client] Client 1, family member 0 went into shelter	available_beds 11
# (day 0)	[client] Client 1, family member 1 went into shelter	available_beds 10
# (day 0)	[client] Client 2 (family size = 4, case type = 3) arrives the shelter	available beds 10.
# (day 0)	[client] Client 2, family member 0 went into shelter	available_beds 9
# (day 0)	[client] Client 2, family member 1 went into shelter	available_beds 8
# (day 0)	[client] Client 2, family member 2 went into shelter	available_beds 7
# (day 0)	[client] Client 2, family member 3 went into shelter	available_beds 6
# (day 0)	[client] Client 3 (family size = 2, case type = 3) arrives the shelter	available beds 6.
# (day 0)	[client] Client 3, family member 0 went into shelter	available_beds 5
# (day 0)	[client] Client 3, family member 1 went into shelter	available_beds 4
# (day 12)	[client] Shelter has sent 3 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 18)	[client] Client 5 (family size = 4, case type = 4) arrives the shelter	available beds 4.
# (day 18)	[client] Client 5, family member 0 went into shelter	available_beds 3
# (day 18)	[client] Client 5, family member 1 went into shelter	available_beds 2
# (day 18)	[client] Client 5, family member 2 went into shelter	available_beds 1
# (day 18)	[client] Client 5, family member 3 went into shelter	available_beds 0
# (day 25)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 6 family of 6
# (day 25)	[client] Shelter has unfortunately turned 6 clients (including their family members) away thus far.
# (day 38)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 7 family of 4
# (day 38)	[client] Shelter has unfortunately turned 10 clients (including their family members) away thus far.
# (day 49)	[client] Shelter has sent 5 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 57)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 9 family of 6
# (day 57)	[client] Shelter has unfortunately turned 16 clients (including their family members) away thus far.
# (day 64)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 10 family of 1
# (day 64)	[client] Shelter has unfortunately turned 17 clients (including their family members) away thus far.
# (day 71)	[client] Shelter has sent 11 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 80)	[client] Shelter has sent 14 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 91)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 13 family of 2
# (day 91)	[client] Shelter has unfortunately turned 19 clients (including their family members) away thus far.
# (day 103)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 14 family of 2
# (day 103)	[client] Shelter has unfortunately turned 21 clients (including their family members) away thus far.
# (day 112)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 15 family of 2
# (day 112)	[client] Shelter has unfortunately turned 23 clients (including their family members) away thus far.
# (day 120)	[client] Client 3, family member 0 came out of shelter	available_beds 1
# (day 120)	[client] Client 3, family member 1 came out of shelter	available_beds 2
# (day 120)	[client] Client 3 (family size = 2, case type = 3) LEAVES the shelter	available beds 2
# (day 125)	[client] Shelter has sent 16 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 129)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 17 family of 5
# (day 129)	[client] Shelter has unfortunately turned 28 clients (including their family members) away thus far.
# (day 137)	[client] Client 18 (family size = 1, case type = 2) arrives the shelter	available beds 2.
# (day 137)	[client] Client 18, family member 0 went into shelter	available_beds 1
# (day 148)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 19 family of 5
# (day 148)	[client] Shelter has unfortunately turned 33 clients (including their family members) away thus far.
# (day 155)	[client] Client 5, family member 0 came out of shelter	available_beds 2
# (day 155)	[client] Client 5, family member 1 came out of shelter	available_beds 3
# (day 155)	[client] Client 5, family member 2 came out of shelter	available_beds 4
# (day 155)	[client] Client 5, family member 3 came out of shelter	available_beds 5
# (day 155)	[client] Client 5 (family size = 4, case type = 4) LEAVES the shelter	available beds 5
# (day 166)	[client] !!!!SHELTER AT CAPACITY. only 5 available beds. Referring out Client 20 family of 6
# (day 166)	[client] Shelter has unfortunately turned 39 clients (including their family members) away thus far.
# (day 172)	[client] Client 21 (family size = 4, case type = 1) arrives the shelter	available beds 5.
# (day 172)	[client] Client 21, family member 0 went into shelter	available_beds 4
# (day 172)	[client] Client 21, family member 1 went into shelter	available_beds 3
# (day 172)	[client] Client 21, family member 2 went into shelter	available_beds 2
# (day 172)	[client] Client 21, family member 3 went into shelter	available_beds 1
# (day 185)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 22 family of 6
# (day 185)	[client] Shelter has unfortunately turned 45 clients (including their family members) away thus far.
# (day 195)	[client] Shelter has sent 17 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 197)	[client] Client 0, family member 0 came out of shelter	available_beds 2
# (day 197)	[client] Client 0, family member 1 came out of shelter	available_beds 3
# (day 197)	[client] Client 0, family member 2 came out of shelter	available_beds 4
# (day 197)	[client] Client 0 (family size = 3, case type = 3) LEAVES the shelter	available beds 4
# (day 202)	[client] Client 24 (family size = 2, case type = 1) arrives the shelter	available beds 4.
# (day 202)	[client] Client 24, family member 0 went into shelter	available_beds 3
# (day 202)	[client] Client 24, family member 1 went into shelter	available_beds 2
# (day 212)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 25 family of 5
# (day 212)	[client] Shelter has unfortunately turned 50 clients (including their family members) away thus far.
# (day 220)	[client] Client 21, family member 0 came out of shelter	available_beds 3
# (day 220)	[client] Client 21, family member 1 came out of shelter	available_beds 4
# (day 220)	[client] Client 21, family member 2 came out of shelter	available_beds 5
# (day 220)	[client] Client 21, family member 3 came out of shelter	available_beds 6
# (day 220)	[client] Client 21 (family size = 4, case type = 1) LEAVES the shelter	available beds 6
# (day 224)	[client] Shelter has sent 22 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 230)	[client] Client 27 (family size = 1, case type = 2) arrives the shelter	available beds 6.
# (day 230)	[client] Client 27, family member 0 went into shelter	available_beds 5
# (day 242)	[client] !!!!SHELTER AT CAPACITY. only 5 available beds. Referring out Client 28 family of 6
# (day 242)	[client] Shelter has unfortunately turned 56 clients (including their family members) away thus far.
# (day 248)	[client] Client 29 (family size = 5, case type = 3) arrives the shelter	available beds 5.
# (day 248)	[client] Client 29, family member 0 went into shelter	available_beds 4
# (day 248)	[client] Client 29, family member 1 went into shelter	available_beds 3
# (day 248)	[client] Client 29, family member 2 went into shelter	available_beds 2
# (day 248)	[client] Client 29, family member 3 went into shelter	available_beds 1
# (day 248)	[client] Client 29, family member 4 went into shelter	available_beds 0
# (day 253)	[client] Client 24, family member 0 came out of shelter	available_beds 1
# (day 253)	[client] Client 24, family member 1 came out of shelter	available_beds 2
# (day 253)	[client] Client 24 (family size = 2, case type = 1) LEAVES the shelter	available beds 2
# (day 254)	[client] !!!!SHELTER AT CAPACITY. only 2 available beds. Referring out Client 30 family of 5
# (day 254)	[client] Shelter has unfortunately turned 61 clients (including their family members) away thus far.
# (day 256)	[client] Shelter has sent 27 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 260)	[client] Client 2, family member 0 came out of shelter	available_beds 3
# (day 260)	[client] Client 2, family member 1 came out of shelter	available_beds 4
# (day 260)	[client] Client 2, family member 2 came out of shelter	available_beds 5
# (day 260)	[client] Client 2, family member 3 came out of shelter	available_beds 6
# (day 260)	[client] Client 2 (family size = 4, case type = 3) LEAVES the shelter	available beds 6
# (day 261)	[client] Client 32 (family size = 5, case type = 2) arrives the shelter	available beds 6.
# (day 261)	[client] Client 32, family member 0 went into shelter	available_beds 5
# (day 261)	[client] Client 32, family member 1 went into shelter	available_beds 4
# (day 261)	[client] Client 32, family member 2 went into shelter	available_beds 3
# (day 261)	[client] Client 32, family member 3 went into shelter	available_beds 2
# (day 261)	[client] Client 32, family member 4 went into shelter	available_beds 1
# (day 267)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 33 family of 6
# (day 267)	[client] Shelter has unfortunately turned 67 clients (including their family members) away thus far.
# (day 273)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 34 family of 4
# (day 273)	[client] Shelter has unfortunately turned 71 clients (including their family members) away thus far.
# (day 283)	[client] Shelter has sent 29 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 287)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 36 family of 3
# (day 287)	[client] Shelter has unfortunately turned 74 clients (including their family members) away thus far.
# (day 291)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 37 family of 5
# (day 291)	[client] Shelter has unfortunately turned 79 clients (including their family members) away thus far.
# (day 298)	[client] !!!!SHELTER AT CAPACITY. only 1 available beds. Referring out Client 38 family of 2
# (day 298)	[client] Shelter has unfortunately turned 81 clients (including their family members) away thus far.
# (day 302)	[client] Client 39 (family size = 1, case type = 3) arrives the shelter	available beds 1.
# (day 302)	[client] Client 39, family member 0 went into shelter	available_beds 0
# (day 307)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 40 family of 3
# (day 307)	[client] Shelter has unfortunately turned 84 clients (including their family members) away thus far.
# (day 311)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 41 family of 5
# (day 311)	[client] Shelter has unfortunately turned 89 clients (including their family members) away thus far.
# (day 313)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 42 family of 2
# (day 313)	[client] Shelter has unfortunately turned 91 clients (including their family members) away thus far.
# (day 320)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 43 family of 6
# (day 320)	[client] Shelter has unfortunately turned 97 clients (including their family members) away thus far.
# (day 321)	[client] Client 1, family member 0 came out of shelter	available_beds 1
# (day 321)	[client] Client 1, family member 1 came out of shelter	available_beds 2
# (day 321)	[client] Client 1 (family size = 2, case type = 2) LEAVES the shelter	available beds 2
# (day 327)	[client] Client 44 (family size = 2, case type = 1) arrives the shelter	available beds 2.
# (day 327)	[client] Client 44, family member 0 went into shelter	available_beds 1
# (day 327)	[client] Client 44, family member 1 went into shelter	available_beds 0
# (day 334)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 45 family of 3
# (day 334)	[client] Shelter has unfortunately turned 100 clients (including their family members) away thus far.
# (day 335)	[client] Shelter has sent 33 clients (including their family members)               with life-threatening situations to undisclosed hotels.
# (day 340)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 47 family of 4
# (day 340)	[client] Shelter has unfortunately turned 104 clients (including their family members) away thus far.
# (day 344)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 48 family of 5
# (day 344)	[client] Shelter has unfortunately turned 109 clients (including their family members) away thus far.
# (day 348)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 49 family of 1
# (day 348)	[client] Shelter has unfortunately turned 110 clients (including their family members) away thus far.
# (day 350)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 50 family of 5
# (day 350)	[client] Shelter has unfortunately turned 115 clients (including their family members) away thus far.
# (day 355)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 51 family of 1
# (day 355)	[client] Shelter has unfortunately turned 116 clients (including their family members) away thus far.
# (day 358)	[client] !!!!SHELTER AT CAPACITY. only 0 available beds. Referring out Client 52 family of 3
# (day 358)	[client] Shelter has unfortunately turned 119 clients (including their family members) away thus far.
# (day 360)	[client] Client 44, family member 0 came out of shelter	available_beds 1
# (day 360)	[client] Client 44, family member 1 came out of shelter	available_beds 2
# (day 360)	[client] Client 44 (family size = 2, case type = 1) LEAVES the shelter	available beds 2

# %%
#Create a persistent CSV file of the simulation runs.
shelter_data.data_table.to_csv("test_run_new_v2.csv",index=False)

# %% [markdown]
# ### Getting average ppl turned away every month -WIP

# %%
m = shelter_data.data_table[['run_number','month','ppl_turned_away']].groupby(['run_number','month']).tail(1).astype(str).astype(int)
# Out:
#    run_number  month  ppl_turned_away
# 0           1      1                3
# 0           1      2                8
# 0           1      3               17
# 0           1      4               23
# 0           1      5               35
# 0           1      6               44
# 0           1      7               59
# 0           1      8               59
# 0           1      9               88
# 0           1     10              101
# 0           1     11              117
# 0           1     12              129
# 0           2      2               21
# 0           2      3               24
# 0           2      4               34
# 0           2      5               34
# 0           2      6               39
# 0           2      7               44
# 0           2      8               54
# 0           2      9               68
# 0           2     10               79
# 0           2     11               96
# 0           2     12              110
# 0           2      1              110
# 0           3      1                5
# 0           3      2                5
# 0           3      3               15
# 0           3      4               17
# 0           3      5               23
# 0           3      6               38
# 0           3      7               44
# 0           3      8               57
# 0           3      9               73
# 0           3     10               86
# 0           3     11              104
# 0           3     12              110
# 0           4      1               12
# 0           4      2               17
# 0           4      3               22
# 0           4      4               24
# 0           4      5               32
# 0           4      6               46
# 0           4      7               52
# 0           4      8               60
# 0           4      9               63
# 0           4     10               83
# 0           4     11              111
# 0           4     12              131
# 0           5      1                6
# 0           5      2               16
# 0           5      3               17
# 0           5      4               23
# 0           5      5               33
# 0           5      6               39
# 0           5      7               45
# 0           5      8               56
# 0           5      9               67
# 0           5     10               81
# 0           5     11               97
# 0           5     12              119

# %%
#function to get average ppl turned away every month --> for each run
def monthly_turn_away(df):
    df['monthly_turn_away'] = df['ppl_turned_away'].diff(1)
    df['monthly_turn_away'].fillna(df['ppl_turned_away'],inplace=True)
    return(df['monthly_turn_away'].to_list())

#To do: Reset the arrival/ppl turned away everytime the code exceeds 12 months and avoid spill over into the next year

# %%
for i in range(0,NUMBER_OF_RUNS):
    run_data = m[m['run_number'] == i]
    print("_________Run ", i ,"_______" )
    print(monthly_turn_away(run_data))
    monthly_turn_away(run_data)

# %% [markdown]
# # Visualization section
# We now take the data generated from the simulation and visualize the output in the code below

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 15})

# path1 ="/Users/sjayab596/Documents/GIT_Personal_Repos/ISYE_6644_Sim/Project/Run1_DataSheet_flatfile.csv"
# path2 ="/Users/sjayab596/Documents/GIT_Personal_Repos/ISYE_6644_Sim/Project/Run2_DataSheet_flatfile.csv"
# path3 ="/Users/sjayab596/Documents/GIT_Personal_Repos/ISYE_6644_Sim/Project/Run3_DataSheet_flatfile.csv"

all_runs=pd.read_csv("test_run_new.csv")
run1 = all_runs[all_runs['run_number'] == 1]
run2 = all_runs[all_runs['run_number'] == 2]
run3 = all_runs[all_runs['run_number'] == 3]

# run1=pd.read_csv(path1)
# run2=pd.read_csv(path2)
# run3=pd.read_csv(path3)

# %%
#%%capture # to hide the warnings

# run1['month'] = run1['month'].apply(lambda x: datetime.strptime(x, "%m").strftime("%B") if x.isdigit() else x)
# run2['month'] = run2['month'].apply(lambda x: datetime.strptime(x, "%m").strftime("%B") if x.isdigit() else x)
# run3['month'] = run3['month'].apply(lambda x: datetime.strptime(x, "%m").strftime("%B") if x.isdigit() else x)
#isinstance(i,int)
run1['month'] = run1['month'].apply(lambda x: datetime.strptime(str(x), "%m").strftime("%B") if isinstance(x,int) else x)
run2['month'] = run2['month'].apply(lambda x: datetime.strptime(str(x), "%m").strftime("%B") if isinstance(x,int) else x)
run3['month'] = run3['month'].apply(lambda x: datetime.strptime(str(x), "%m").strftime("%B") if isinstance(x,int) else x)


occ_monthly1=run1
occ_monthly2=run2
occ_monthly3=run3

occ_monthly1=occ_monthly1.assign(daily_occ= lambda x: (35-x['shelter_capacity_left']))
occ_monthly2=occ_monthly2.assign(daily_occ= lambda x: (35-x['shelter_capacity_left']))
occ_monthly3=occ_monthly3.assign(daily_occ= lambda x: (35-x['shelter_capacity_left']))
# Out:
# /Users/oansari/Documents/marketing/src/knail1/sim-team-z/learning-simpy/venv/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/oansari/Documents/marketing/src/knail1/sim-team-z/learning-simpy/venv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/oansari/Documents/marketing/src/knail1/sim-team-z/learning-simpy/venv/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## Occupancy over time

# %%
# Prep the data - Occupancy over months
# =====================================

# occ_monthly1=run1
# occ_monthly2=run2
# occ_monthly3=run3

# occ_monthly1=occ_monthly1.assign(daily_occ= lambda x: (35-x['shelter_capacity_left']))
# occ_monthly2=occ_monthly2.assign(daily_occ= lambda x: (35-x['shelter_capacity_left']))
# occ_monthly3=occ_monthly3.assign(daily_occ= lambda x: (35-x['shelter_capacity_left']))

occ_monthly1 = occ_monthly1.groupby(["run_number", "month"]).agg(monthly_occupancy =("daily_occ", "sum"))
occ_monthly2 = occ_monthly2.groupby(["run_number", "month"]).agg(monthly_occupancy =("daily_occ", "sum"))
occ_monthly3 = occ_monthly3.groupby(["run_number", "month"]).agg(monthly_occupancy =("daily_occ", "sum"))

#.agg(min_height=('height', 'min')
#occ_monthly.rename_col_by_index(0,'monthly_occupancy')
#occ_monthly=occ_monthly.rename(columns={occ_monthly.columns[0]: 'monthly_occupancy'})
occ_monthly1.reset_index(inplace=True)
occ_monthly2.reset_index(inplace=True)
occ_monthly3.reset_index(inplace=True)

occ_monthlyall = pd.concat([occ_monthly1,occ_monthly2,occ_monthly3])

occ_months1=occ_monthlyall[(occ_monthlyall['run_number'] == 1)]
occ_months2=occ_monthlyall[(occ_monthlyall['run_number'] == 2)]
occ_months3=occ_monthlyall[(occ_monthlyall['run_number'] == 3)] 
                          

months = ["January", "February", "March", "April", "May", "June","July", "August", "September", "October", \
          "November", "December"]
occ_monthly1['month'] = pd.Categorical(occ_monthly1['month'], categories=months, ordered=True)
occ_monthly1=occ_monthly1.sort_values('month', ascending=False)
occ_monthly2['month'] = pd.Categorical(occ_monthly2['month'], categories=months, ordered=True)
occ_monthly2=occ_monthly2.sort_values('month', ascending=False)
occ_monthly3['month'] = pd.Categorical(occ_monthly3['month'], categories=months, ordered=True)
occ_monthly3=occ_monthly3.sort_values('month', ascending=False)
occ_monthly_mean = occ_monthlyall.groupby(["month"]).agg(monthly_occupancy =("monthly_occupancy", "mean"))
occ_monthly_mean['run_number']=0
occ_monthly_mean.reset_index(inplace=True)
occ_monthly_mean['month'] = pd.Categorical(occ_monthly_mean['month'], categories=months, ordered=True)
occ_monthly_mean=occ_monthly_mean.sort_values('month', ascending=False)




## Visualize - Over Months
# ========================

titlestr = 'Occupancy in PersonNights for run#: '+ str(occ_monthly1.loc[1,'run_number'])
plt.title(titlestr,fontsize=30)
plt.barh(occ_monthly1['month'],occ_monthly1['monthly_occupancy'])
 
for index, value in enumerate(occ_monthly1['monthly_occupancy']):
    plt.text(value, index,
             str(value))

plt.show()

# %% [markdown]
# ## Mean Occupancy

# %%
## Visualize - Over Runs 
# =======================

occ_monthly_mean=occ_monthly_mean.sort_values('month', ascending=True)
occ_monthly1=occ_monthly1.sort_values('month', ascending=True)
occ_monthly2=occ_monthly2.sort_values('month', ascending=True)
occ_monthly3=occ_monthly3.sort_values('month', ascending=True)


titlestr = 'Occupancy in PersonNights across runs'
plt.title(titlestr,fontsize=30)

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()

plt.plot(occ_monthly1['month'], occ_monthly1['monthly_occupancy'], label = "Run 1", linestyle='dashed')
plt.plot(occ_monthly2['month'], occ_monthly2['monthly_occupancy'], label = "Run 2",linestyle='dashed')
plt.plot(occ_monthly3['month'], occ_monthly3['monthly_occupancy'], label = "Run 3",linestyle='dashed')
plt.plot(occ_monthly_mean['month'], occ_monthly_mean['monthly_occupancy'], label = "MeanOfRuns",ms=30)
occ_monthly_mean
plt.legend()
spacing = 0.100
fig.subplots_adjust(bottom=spacing)
plt.show()

# %% [markdown]
# ## Surplus capacity over time

# %%
# Prep the data - Surplus capacity over months
# ===========================================

spc_monthly1=run1
spc_monthly2=run2
spc_monthly3=run3

spc_monthly1 = spc_monthly1.groupby(["run_number", "month"]).agg(monthly_spc =("shelter_capacity_left", "sum"))
spc_monthly2 = spc_monthly2.groupby(["run_number", "month"]).agg(monthly_spc =("shelter_capacity_left", "sum"))
spc_monthly3 = spc_monthly3.groupby(["run_number", "month"]).agg(monthly_spc =("shelter_capacity_left", "sum"))


spc_monthly1.reset_index(inplace=True)
spc_monthly2.reset_index(inplace=True)
spc_monthly3.reset_index(inplace=True)

spc_monthlyall = pd.concat([spc_monthly1,spc_monthly2,spc_monthly3])

spc_months1=spc_monthlyall[(spc_monthlyall['run_number'] == 1)]
spc_months2=spc_monthlyall[(spc_monthlyall['run_number'] == 2)]
spc_months3=spc_monthlyall[(spc_monthlyall['run_number'] == 3)] 
                          

months = ["January", "February", "March", "April", "May", "June","July", "August", "September", "October", \
          "November", "December"]
spc_monthly1['month'] = pd.Categorical(spc_monthly1['month'], categories=months, ordered=True)
spc_monthly1=spc_monthly1.sort_values('month', ascending=False)
spc_monthly2['month'] = pd.Categorical(spc_monthly2['month'], categories=months, ordered=True)
spc_monthly2=spc_monthly2.sort_values('month', ascending=False)
spc_monthly3['month'] = pd.Categorical(spc_monthly3['month'], categories=months, ordered=True)
spc_monthly3=spc_monthly3.sort_values('month', ascending=False)
spc_monthly_mean = spc_monthlyall.groupby(["month"]).agg(monthly_spc =("monthly_spc", "mean"))
spc_monthly_mean['run_number']=0
spc_monthly_mean.reset_index(inplace=True)
spc_monthly_mean['month'] = pd.Categorical(spc_monthly_mean['month'], categories=months, ordered=True)
spc_monthly_mean=spc_monthly_mean.sort_values('month', ascending=False)


## Visualize - Over Months
# ========================

titlestr = 'Surplus Capacity in PersonNights for run#: '+ str(spc_monthly1.loc[1,'run_number'])
plt.title(titlestr,fontsize=30)
plt.barh(spc_monthly1['month'],spc_monthly1['monthly_spc'])
 
for index, value in enumerate(spc_monthly1['monthly_spc']):
    plt.text(value, index,
             str(value))

plt.show()

# %% [markdown]
# ## mean surplus capacity

# %%
## Visualize - Over Runs 
# =======================

spc_monthly_mean=spc_monthly_mean.sort_values('month', ascending=True)
spc_monthly1=spc_monthly1.sort_values('month', ascending=True)
spc_monthly2=spc_monthly2.sort_values('month', ascending=True)
spc_monthly3=spc_monthly3.sort_values('month', ascending=True)

titlestr = 'Surplus Capacity in PersonNights across runs'
plt.title(titlestr,fontsize=30)

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True
#fig = plt.figure()

plt.plot(spc_monthly1['month'], spc_monthly1['monthly_spc'], label = "Run 1", linestyle='dashed')
plt.plot(spc_monthly2['month'], spc_monthly2['monthly_spc'], label = "Run 2",linestyle='dashed')
plt.plot(spc_monthly3['month'], spc_monthly3['monthly_spc'], label = "Run 3",linestyle='dashed')
plt.plot(spc_monthly_mean['month'], spc_monthly_mean['monthly_spc'], label = "MeanOfRuns",ms=50)
occ_monthly_mean
plt.legend()
spacing = 0.100
fig.subplots_adjust(bottom=spacing)
plt.show()

# %% [markdown]
# ## Abuse victims turned away

# %%
# Prep the data - Abuse victims turned away over months
# ======================================================

avt_monthly1=run1
avt_monthly2=run2
avt_monthly3=run3

avt_monthly1 = avt_monthly1.groupby(["run_number", "month"]).agg(monthly_avt =("ppl_turned_away", "sum"))
avt_monthly2 = avt_monthly2.groupby(["run_number", "month"]).agg(monthly_avt =("ppl_turned_away", "sum"))
avt_monthly3 = avt_monthly3.groupby(["run_number", "month"]).agg(monthly_avt =("ppl_turned_away", "sum"))


avt_monthly1.reset_index(inplace=True)
avt_monthly2.reset_index(inplace=True)
avt_monthly3.reset_index(inplace=True)

avt_monthlyall = pd.concat([avt_monthly1,avt_monthly2,avt_monthly3])

avt_months1=avt_monthlyall[(avt_monthlyall['run_number'] == 1)]
avt_months2=avt_monthlyall[(avt_monthlyall['run_number'] == 2)]
avt_months3=avt_monthlyall[(avt_monthlyall['run_number'] == 3)] 
                          

months = ["January", "February", "March", "April", "May", "June","July", "August", "September", "October", \
          "November", "December"]
avt_monthly1['month'] = pd.Categorical(avt_monthly1['month'], categories=months, ordered=True)
avt_monthly1=avt_monthly1.sort_values('month', ascending=False)
avt_monthly2['month'] = pd.Categorical(avt_monthly2['month'], categories=months, ordered=True)
avt_monthly2=avt_monthly2.sort_values('month', ascending=False)
avt_monthly3['month'] = pd.Categorical(avt_monthly3['month'], categories=months, ordered=True)
avt_monthly3=avt_monthly3.sort_values('month', ascending=False)
avt_monthly_mean = avt_monthlyall.groupby(["month"]).agg(monthly_avt =("monthly_avt", "mean"))
avt_monthly_mean['run_number']=0
avt_monthly_mean.reset_index(inplace=True)
avt_monthly_mean['month'] = pd.Categorical(avt_monthly_mean['month'], categories=months, ordered=True)
avt_monthly_mean=avt_monthly_mean.sort_values('month', ascending=False)


## Visualize - Over Months
# ========================

titlestr = 'People turned away for run#: '+ str(avt_monthly1.loc[1,'run_number'])
plt.title(titlestr,fontsize=30)
plt.barh(avt_monthly1['month'],avt_monthly1['monthly_avt'])
 
for index, value in enumerate(avt_monthly1['monthly_avt']):
    plt.text(value, index,
             str(value))

plt.show()

# %% [markdown]
# ## Mean number of abuse victims turned away

# %%
## Visualize - Over Runs 
# =======================

avt_monthly_mean=avt_monthly_mean.sort_values('month', ascending=True)
avt_monthly1=avt_monthly1.sort_values('month', ascending=True)
avt_monthly2=avt_monthly2.sort_values('month', ascending=True)
avt_monthly3=avt_monthly3.sort_values('month', ascending=True)

titlestr = 'Number of victims turned away across runs'
plt.title(titlestr,fontsize=30)

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True
#fig = plt.figure()

plt.plot(avt_monthly1['month'], avt_monthly1['monthly_avt'], label = "Run 1", linestyle='dashed')
plt.plot(avt_monthly2['month'], avt_monthly2['monthly_avt'], label = "Run 2",linestyle='dashed')
plt.plot(avt_monthly3['month'], avt_monthly3['monthly_avt'], label = "Run 3",linestyle='dashed')
plt.plot(avt_monthly_mean['month'], avt_monthly_mean['monthly_avt'], label = "MeanOfRuns",ms=50)
plt.legend()
spacing = 0.100
fig.subplots_adjust(bottom=spacing)
plt.show()

# %% [markdown]
# ## victims sent to hotels

# %%
# Prep the data - Abuse victims turned away over months
# ======================================================

vsh_monthly1=run1
vsh_monthly2=run2
vsh_monthly3=run3

vsh_monthly1 = vsh_monthly1.groupby(["run_number", "month"]).agg(monthly_vsh =("sent_to_hotel", "sum"))
vsh_monthly2 = vsh_monthly2.groupby(["run_number", "month"]).agg(monthly_vsh =("sent_to_hotel", "sum"))
vsh_monthly3 = vsh_monthly3.groupby(["run_number", "month"]).agg(monthly_vsh =("sent_to_hotel", "sum"))


vsh_monthly1.reset_index(inplace=True)
vsh_monthly2.reset_index(inplace=True)
vsh_monthly3.reset_index(inplace=True)

vsh_monthlyall = pd.concat([vsh_monthly1,vsh_monthly2,vsh_monthly3])

vsh_months1=vsh_monthlyall[(vsh_monthlyall['run_number'] == 1)]
vsh_months2=vsh_monthlyall[(vsh_monthlyall['run_number'] == 2)]
vsh_months3=vsh_monthlyall[(vsh_monthlyall['run_number'] == 3)] 
                          

months = ["January", "February", "March", "April", "May", "June","July", "August", "September", "October", \
          "November", "December"]
vsh_monthly1['month'] = pd.Categorical(vsh_monthly1['month'], categories=months, ordered=True)
vsh_monthly1=vsh_monthly1.sort_values('month', ascending=False)
vsh_monthly2['month'] = pd.Categorical(vsh_monthly2['month'], categories=months, ordered=True)
vsh_monthly2=vsh_monthly2.sort_values('month', ascending=False)
vsh_monthly3['month'] = pd.Categorical(vsh_monthly3['month'], categories=months, ordered=True)
vsh_monthly3=vsh_monthly3.sort_values('month', ascending=False)
vsh_monthly_mean = vsh_monthlyall.groupby(["month"]).agg(monthly_vsh =("monthly_vsh", "mean"))
vsh_monthly_mean['run_number']=0
vsh_monthly_mean.reset_index(inplace=True)
vsh_monthly_mean['month'] = pd.Categorical(vsh_monthly_mean['month'], categories=months, ordered=True)
vsh_monthly_mean=vsh_monthly_mean.sort_values('month', ascending=False)


## Visualize - Over Months
# ========================

titlestr = 'People sent to hotels for run#: '+ str(vsh_monthly1.loc[1,'run_number'])
plt.title(titlestr,fontsize=30)
plt.barh(vsh_monthly1['month'],vsh_monthly1['monthly_vsh'])
 
for index, value in enumerate(vsh_monthly1['monthly_vsh']):
    plt.text(value, index,
             str(value))

plt.show()

# %% [markdown]
# ## mean number of victims sent to hotels

# %%
## Visualize - Over Runs 
# =======================


vsh_monthly_mean=vsh_monthly_mean.sort_values('month', ascending=True)
vsh_monthly1=vsh_monthly1.sort_values('month', ascending=True)
vsh_monthly2=vsh_monthly2.sort_values('month', ascending=True)
vsh_monthly3=vsh_monthly3.sort_values('month', ascending=True)

titlestr = 'People sent to hotels across runs'
plt.title(titlestr,fontsize=30)

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True
#fig = plt.figure()

plt.plot(vsh_monthly1['month'], vsh_monthly1['monthly_vsh'], label = "Run 1", linestyle='dashed')
plt.plot(vsh_monthly2['month'], vsh_monthly2['monthly_vsh'], label = "Run 2",linestyle='dashed')
plt.plot(vsh_monthly3['month'], vsh_monthly3['monthly_vsh'], label = "Run 3",linestyle='dashed')
plt.plot(vsh_monthly_mean['month'], vsh_monthly_mean['monthly_vsh'], label = "MeanOfRuns",ms=50)
plt.legend()
spacing = 0.100
fig.subplots_adjust(bottom=spacing)
plt.show()

# %% [markdown]
# ## NHPP implementation for incoming clients

# %%
## Lets assume the average number of entries in the shelter on non-holiday season is 20 and holiday season is 30
## Each entry could be between 1 to 4 women arriving at shelter
#defining non-homogenous poison process with arrival rates varying between 1 to 4 in the day
def nhpp_arrival():
    t = 0
    potential_arr_time = 0
    arrival_times = []
    arrival_rate = []

  #defining a period function where arrival rate varies from 1 to 4
    ld = 3.5 + 2.5*math.sin(t/2)
    
  #max_arrivals
    ld_0 = 6                 
  
    for month in range(1,12):
        if (month <= 8):
            n = 20
        else:
            n = 30
        
        #generates arrival for each month
        for i in range(0,n):
            ld = 3.5 + 2.5*math.sin(t/2)
            
            #generate a uniform sample
            U = random.uniform(0,1)
            
            #calculating exponential arrival time 
            potential_intr_arr = -1/ld_0 * math.log(U)  

            #bootstraping to get arrival times for each arrival
            potential_arr_time += potential_intr_arr 

            #assign the new arrival time to t
            t = potential_arr_time

            #generate a uniform to test the probability of accepting or rejecting the potential arrival (Thinning algorithm)
            V =  random.uniform(0,1)
            prob = ld / ld_0

       #accept t if V < prob
            if V <= prob:
                 arrival_times.append(t)
            i+=1
            
    for j in range(0,len(arrival_times)):
        x = 3.5 + 2.5*math.sin(arrival_times[j]/2)
        arrival_rate.append(x)
    
    #generate client type for each arrival 
    client_type = list(np.random.choice([1,2,3,4],len(arrival_times), p=[0.25,0.25,0.25,0.25]))
    
    return(arrival_times,arrival_rate,client_type)

# %% [markdown]
# #### References :
# ##### https://hpaulkeeler.com/simulating-an-inhomogeneous-poisson-point-process/
# ##### https://stackoverflow.com/questions/32712409/how-to-sample-inhomogeneous-poisson-processes-in-python-faster-than-this

# %%
# Arrivals on a weekday:
arrival_times,arrival_rate,client_type = nhpp_arrival()

# plotting the arrival rates at each arrival time ---> non-homogeneous poisson process
#plt.plot(arrival_times,arrival_rate, color='red', linestyle='dashed', linewidth = 2,
#         marker='o', markerfacecolor='blue', markersize=5 )
#plt.title('NHPP Arrivals for the year')

# %%
arrival_times
# Out:
# [0.1395290596585066,
#  0.23091612497368083,
#  0.3009949093705109,
#  0.9923328849970515,
#  1.0660126396025387,
#  1.298077133431062,
#  1.3568816279475395,
#  1.5367692129075128,
#  1.5600058609684124,
#  1.7123944929437247,
#  1.7885633515772712,
#  1.837376664073683,
#  1.9820265760114406,
#  2.14771137442093,
#  2.1897991258059726,
#  2.6007340528540923,
#  2.908884397233602,
#  2.9746463293286207,
#  3.0434100520593836,
#  3.17946762405882,
#  3.2263197638868686,
#  3.3670149210587272,
#  3.431663430756698,
#  3.4991245164362454,
#  3.653825001564925,
#  4.465193920561969,
#  4.724325396167146,
#  4.951734818762641,
#  5.762177902632667,
#  6.052012380874742,
#  6.1105863787587555,
#  7.106461776969836,
#  7.629578054250884,
#  7.911134671904597,
#  7.939306182397835,
#  10.074708413204018,
#  12.440936823632658,
#  12.557598840589604,
#  12.781869309625915,
#  13.09710195754763,
#  13.65325443417743,
#  13.767269486687903,
#  13.999829559971618,
#  14.136878814288197,
#  14.443620235659044,
#  14.65406765221926,
#  14.834671608846753,
#  14.87412183889207,
#  15.327361334025758,
#  15.39203610766623,
#  15.44592474668484,
#  15.462314378604628,
#  15.645402075970217,
#  15.971395715022474,
#  15.976868509351746,
#  16.132968613977432,
#  16.143635778148404,
#  16.306362628249264,
#  16.340828779731744,
#  16.37209288222266,
#  16.435048149117506,
#  16.50786770807577,
#  16.6772987167281,
#  16.962855185261766,
#  16.97181364638305,
#  17.219283696582085,
#  17.64625172994115,
#  18.02812540206727,
#  18.604294784164495,
#  18.648656720408614,
#  18.811365623066514,
#  18.87746773330664,
#  19.015181449491685,
#  19.08035236280135,
#  19.215599574811623,
#  19.263872122801942,
#  19.368428549577803,
#  19.403832116361794,
#  19.433863410308415,
#  19.57173041949829,
#  19.77482263927297,
#  20.434653989723603,
#  20.479711346352094,
#  20.496291686360152,
#  21.060067740187954,
#  21.95316016995273,
#  22.861317652508525,
#  23.933153183833824,
#  24.20827640565288,
#  25.14611839133806,
#  25.524536687094802,
#  25.59268903649869,
#  25.59696774300564,
#  25.704024586123897,
#  25.705980773751968,
#  25.86272174029908,
#  26.16686730010782,
#  26.206466881380937,
#  26.25824855508108,
#  26.301484692763065,
#  26.484994602000345,
#  26.58584645686385,
#  26.876256479741887,
#  27.00401134152412,
#  27.08055866395972,
#  27.54106299706962,
#  27.671327322448185,
#  28.19265702111063,
#  28.721378296098546,
#  28.83185226644277,
#  28.933617170978277,
#  28.980834467548576,
#  29.152516440190954,
#  29.176533662516466,
#  29.523808715886574,
#  29.543327204208445,
#  29.56188331692933,
#  29.566321285255047,
#  29.791893407041293,
#  29.845012897838807,
#  29.92947041932823,
#  30.03048698751169,
#  30.45129825862051,
#  30.648390099252627,
#  30.790564015630952,
#  30.964799333992925,
#  30.988002557042346,
#  30.98831107612279,
#  31.42329329633972,
#  32.022003311449886,
#  33.44049868530776,
#  34.33509292044406,
#  34.98906552116023,
#  37.1298128741016,
#  37.26945031493458,
#  38.53196869553251,
#  38.844838074271884,
#  39.03336370989528,
#  39.228741065364225,
#  39.459387073974355,
#  39.55877179454859,
#  39.757872044348936,
#  39.87254105901024,
#  39.88256894264237,
#  39.95214180566287,
#  40.03585801358514]

# %%
# round off arrivals
fig, ax = plt.subplots(figsize =(10, 7))
# mirror the arrivals to make it skewed for smaller arrivals compared to larger ones (can be removed if needed)
ax.hist([7-round(i) for i in arrival_rate],bins=6)
plt.title('Histogram of arrivals')
# Out:
# Text(0.5, 1.0, 'Histogram of arrivals')
